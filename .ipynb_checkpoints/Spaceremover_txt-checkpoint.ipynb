# %%
# opening and creating new .txt file 
with open( 
	"a.txt", 'r') as r, open( 
		'WorkloadsDistributionTestOutput.txt', 'w') as o: 
	
	for line in r: 
		#strip() function 
		if line.strip(): 
			o.write(line) 

f = open("a.txt", "r") 
print("New text file:\n",f.read())
# Out:
# New text file:
#  Record Count: 1000
# Zipfian
# [OVERALL], RunTime(ms), 774
# [OVERALL], Throughput(ops/sec), 1291.9896640826873
# [TOTAL_GCS_PS_Scavenge], Count, 2
# [TOTAL_GC_TIME_PS_Scavenge], Time(ms), 10
# [TOTAL_GC_TIME_%_PS_Scavenge], Time(%), 1.2919896640826873
# [TOTAL_GCS_PS_MarkSweep], Count, 0
# [TOTAL_GC_TIME_PS_MarkSweep], Time(ms), 0
# [TOTAL_GC_TIME_%_PS_MarkSweep], Time(%), 0.0
# [TOTAL_GCs], Count, 2
# [TOTAL_GC_TIME], Time(ms), 10
# [TOTAL_GC_TIME_%], Time(%), 1.2919896640826873
# [READ], Operations, 502
# [READ], AverageLatency(us), 491.0796812749004
# [READ], MinLatency(us), 138
# [READ], MaxLatency(us), 66239
# [READ], 95thPercentileLatency(us), 666
# [READ], 99thPercentileLatency(us), 2353
# [READ], Return=OK, 502
# [CLEANUP], Operations, 1
# [CLEANUP], AverageLatency(us), 3609.0
# [CLEANUP], MinLatency(us), 3608
# [CLEANUP], MaxLatency(us), 3609
# [CLEANUP], 95thPercentileLatency(us), 3609
# [CLEANUP], 99thPercentileLatency(us), 3609
# ...
