# %%
# opening and creating new .txt file 
with open( 
	"a.txt", 'r') as r, open( 
		'YCSB_Workload_Outputs.txt', 'w') as o: 
	
	for line in r: 
		#strip() function 
		if line.strip(): 
			o.write(line) 

f = open("a.txt", "r") 
print("New text file:\n",f.read())
# Out:
# New text file:
#  #### MySQL ####
#
# ----1000 Rows:
# [OVERALL], RunTime(ms), 3320
# [OVERALL], Throughput(ops/sec), 301.2048192771084
# [TOTAL_GCS_PS_Scavenge], Count, 3
# [TOTAL_GC_TIME_PS_Scavenge], Time(ms), 13
# [TOTAL_GC_TIME_%_PS_Scavenge], Time(%), 0.391566265060241
# [TOTAL_GCS_PS_MarkSweep], Count, 0
# [TOTAL_GC_TIME_PS_MarkSweep], Time(ms), 0
# [TOTAL_GC_TIME_%_PS_MarkSweep], Time(%), 0.0
# [TOTAL_GCs], Count, 3
# [TOTAL_GC_TIME], Time(ms), 13
# [TOTAL_GC_TIME_%], Time(%), 0.391566265060241
# [CLEANUP], Operations, 1
# [CLEANUP], AverageLatency(us), 1627.0
# [CLEANUP], MinLatency(us), 1627
# [CLEANUP], MaxLatency(us), 1627
# [CLEANUP], 95thPercentileLatency(us), 1627
# [CLEANUP], 99thPercentileLatency(us), 1627
# [INSERT], Operations, 1000
# [INSERT], AverageLatency(us), 2899.013
# [INSERT], MinLatency(us), 1774
# [INSERT], MaxLatency(us), 41407
# [INSERT], 95thPercentileLatency(us), 4955
# [INSERT], 99thPercentileLatency(us), 8159
# [INSERT], Return=OK, 1000
#
# ...
