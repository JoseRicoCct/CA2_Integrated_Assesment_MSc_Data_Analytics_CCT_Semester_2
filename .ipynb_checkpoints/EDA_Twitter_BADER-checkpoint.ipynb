# %%
import pandas as pd
import re
from collections import Counter
from textblob import TextBlob

# %%
df = pd.read_csv('processed_tweets.csv').reset_index(drop=True)

# %%
df
# Out:
#              ids    tweet_id                 date      flag             user  \
# 0              1  1467810672  2009-04-06 22:19:49  NO_QUERY    scotthamilton
# 1              2  1467810917  2009-04-06 22:19:53  NO_QUERY         mattycus
# 2              3  1467811184  2009-04-06 22:19:57  NO_QUERY          ElleCTF
# 3              4  1467811193  2009-04-06 22:19:57  NO_QUERY           Karoli
# 4              5  1467811372  2009-04-06 22:20:00  NO_QUERY         joy_wolf
# ...          ...         ...                  ...       ...              ...
# 1598309  1598310  2193601966  2009-06-16 08:40:49  NO_QUERY  AmandaMarie1028
# 1598310  1598311  2193601969  2009-06-16 08:40:49  NO_QUERY      TheWDBoards
# 1598311  1598312  2193601991  2009-06-16 08:40:49  NO_QUERY           bpbabe
# 1598312  1598313  2193602064  2009-06-16 08:40:49  NO_QUERY     tinydiamondz
# 1598313  1598314  2193602129  2009-06-16 08:40:50  NO_QUERY   RyanTrevMorris
#
#                                                      tweet  sentiment
# 0        upset cant update facebook texting might cry r...      0.000
# 1        dived many times ball managed save rest go bounds      0.500
# 2                         whole body feels itchy like fire      0.200
# 3                                 behaving im mad cant see     -0.625
# 4                                               whole crew      0.200
# ...                                                    ...        ...
# 1598309                      woke school best feeling ever      1.000
# 1598310            thewdbcom cool hear old walt interviews      0.225
# 1598311                    ready mojo makeover ask details      0.200
# 1598312  happy th birthday boo alll time tupac amaru sh...      0.800
# 1598313                                              happy      0.800
#
# [1598314 rows x 7 columns]

# %% [markdown]
# We can see that index and ids are out of sequence...

# %%
# Assuming df is your DataFrame
# Drop rows where 'tweet' is NaN
df = df.dropna(subset=['tweet'])

# Now, df no longer contains any rows with NaN in the 'tweet' column

# %%
df
# Out:
#              ids    tweet_id                 date      flag             user  \
# 0              1  1467810672  2009-04-06 22:19:49  NO_QUERY    scotthamilton
# 1              2  1467810917  2009-04-06 22:19:53  NO_QUERY         mattycus
# 2              3  1467811184  2009-04-06 22:19:57  NO_QUERY          ElleCTF
# 3              4  1467811193  2009-04-06 22:19:57  NO_QUERY           Karoli
# 4              5  1467811372  2009-04-06 22:20:00  NO_QUERY         joy_wolf
# ...          ...         ...                  ...       ...              ...
# 1598309  1598310  2193601966  2009-06-16 08:40:49  NO_QUERY  AmandaMarie1028
# 1598310  1598311  2193601969  2009-06-16 08:40:49  NO_QUERY      TheWDBoards
# 1598311  1598312  2193601991  2009-06-16 08:40:49  NO_QUERY           bpbabe
# 1598312  1598313  2193602064  2009-06-16 08:40:49  NO_QUERY     tinydiamondz
# 1598313  1598314  2193602129  2009-06-16 08:40:50  NO_QUERY   RyanTrevMorris
#
#                                                      tweet  sentiment
# 0        upset cant update facebook texting might cry r...      0.000
# 1        dived many times ball managed save rest go bounds      0.500
# 2                         whole body feels itchy like fire      0.200
# 3                                 behaving im mad cant see     -0.625
# 4                                               whole crew      0.200
# ...                                                    ...        ...
# 1598309                      woke school best feeling ever      1.000
# 1598310            thewdbcom cool hear old walt interviews      0.225
# 1598311                    ready mojo makeover ask details      0.200
# 1598312  happy th birthday boo alll time tupac amaru sh...      0.800
# 1598313                                              happy      0.800
#
# [1590343 rows x 7 columns]

# %%
# Reset the index and drop the old one
df = df.reset_index(drop=True)

# %%
df
# Out:
#              ids    tweet_id                 date      flag             user  \
# 0              1  1467810672  2009-04-06 22:19:49  NO_QUERY    scotthamilton
# 1              2  1467810917  2009-04-06 22:19:53  NO_QUERY         mattycus
# 2              3  1467811184  2009-04-06 22:19:57  NO_QUERY          ElleCTF
# 3              4  1467811193  2009-04-06 22:19:57  NO_QUERY           Karoli
# 4              5  1467811372  2009-04-06 22:20:00  NO_QUERY         joy_wolf
# ...          ...         ...                  ...       ...              ...
# 1590338  1598310  2193601966  2009-06-16 08:40:49  NO_QUERY  AmandaMarie1028
# 1590339  1598311  2193601969  2009-06-16 08:40:49  NO_QUERY      TheWDBoards
# 1590340  1598312  2193601991  2009-06-16 08:40:49  NO_QUERY           bpbabe
# 1590341  1598313  2193602064  2009-06-16 08:40:49  NO_QUERY     tinydiamondz
# 1590342  1598314  2193602129  2009-06-16 08:40:50  NO_QUERY   RyanTrevMorris
#
#                                                      tweet  sentiment
# 0        upset cant update facebook texting might cry r...      0.000
# 1        dived many times ball managed save rest go bounds      0.500
# 2                         whole body feels itchy like fire      0.200
# 3                                 behaving im mad cant see     -0.625
# 4                                               whole crew      0.200
# ...                                                    ...        ...
# 1590338                      woke school best feeling ever      1.000
# 1590339            thewdbcom cool hear old walt interviews      0.225
# 1590340                    ready mojo makeover ask details      0.200
# 1590341  happy th birthday boo alll time tupac amaru sh...      0.800
# 1590342                                              happy      0.800
#
# [1590343 rows x 7 columns]

# %%
# Resetting the 'ids' column to have a sequential count starting from 1
df['ids'] = range(1, len(df) + 1)

# %%
df
# Out:
#              ids    tweet_id                 date      flag             user  \
# 0              1  1467810672  2009-04-06 22:19:49  NO_QUERY    scotthamilton
# 1              2  1467810917  2009-04-06 22:19:53  NO_QUERY         mattycus
# 2              3  1467811184  2009-04-06 22:19:57  NO_QUERY          ElleCTF
# 3              4  1467811193  2009-04-06 22:19:57  NO_QUERY           Karoli
# 4              5  1467811372  2009-04-06 22:20:00  NO_QUERY         joy_wolf
# ...          ...         ...                  ...       ...              ...
# 1590338  1590339  2193601966  2009-06-16 08:40:49  NO_QUERY  AmandaMarie1028
# 1590339  1590340  2193601969  2009-06-16 08:40:49  NO_QUERY      TheWDBoards
# 1590340  1590341  2193601991  2009-06-16 08:40:49  NO_QUERY           bpbabe
# 1590341  1590342  2193602064  2009-06-16 08:40:49  NO_QUERY     tinydiamondz
# 1590342  1590343  2193602129  2009-06-16 08:40:50  NO_QUERY   RyanTrevMorris
#
#                                                      tweet  sentiment
# 0        upset cant update facebook texting might cry r...      0.000
# 1        dived many times ball managed save rest go bounds      0.500
# 2                         whole body feels itchy like fire      0.200
# 3                                 behaving im mad cant see     -0.625
# 4                                               whole crew      0.200
# ...                                                    ...        ...
# 1590338                      woke school best feeling ever      1.000
# 1590339            thewdbcom cool hear old walt interviews      0.225
# 1590340                    ready mojo makeover ask details      0.200
# 1590341  happy th birthday boo alll time tupac amaru sh...      0.800
# 1590342                                              happy      0.800
#
# [1590343 rows x 7 columns]

# %%
df = df.drop('sentiment', axis=1)

# %%
# Convert 'date' to datetime format
df['date'] = pd.to_datetime(df['date'])
# Calculatint the time difference
time_difference = df['date'].iloc[-1] - df['date'].iloc[0]

# Print the result
print('First tweet send out the 2009-04-06 22:19:49 and last one  2009-06-16 08:40:50')

# Print the result
print('Total time difference:',time_difference)
# Out:
# First tweet send out the 2009-04-06 22:19:49 and last one  2009-06-16 08:40:50
# Total time difference: 70 days 10:21:01

# %%
df.head(1)
# Out:
#    ids    tweet_id                date      flag           user  \
# 0    1  1467810672 2009-04-06 22:19:49  NO_QUERY  scotthamilton
#
#                                                tweet
# 0  upset cant update facebook texting might cry r...

# %% [markdown]
# Now index and ids are in sequence.

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
from tqdm.auto import tqdm

# Download VADER lexicon
nltk.download('vader_lexicon')

# Initialize VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Define the function to get VADER sentiment scores
def get_vader_score(tweet):
    score = sia.polarity_scores(tweet)
    return score['compound']  # Returns the compound score which is a combined sentiment score

# Importing tqdm module to track progress
from tqdm.auto import tqdm
tqdm.pandas(desc="Analyzing Sentiments")


# Apply the sentiment analysis function with progress tracking
df['vader_score'] = df['tweet'].progress_apply(get_vader_score)

# Save the results to a CSV file
df.to_csv('tweets_with_vader_scores.csv', index=False)

# Print the first few entries to verify
print(df.head())
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jose\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Analyzing Sentiments:   0%|          | 0/1590343 [00:00<?, ?it/s]
#    ids    tweet_id                date      flag           user  \
# 0    1  1467810672 2009-04-06 22:19:49  NO_QUERY  scotthamilton
# 1    2  1467810917 2009-04-06 22:19:53  NO_QUERY       mattycus
# 2    3  1467811184 2009-04-06 22:19:57  NO_QUERY        ElleCTF
# 3    4  1467811193 2009-04-06 22:19:57  NO_QUERY         Karoli
# 4    5  1467811372 2009-04-06 22:20:00  NO_QUERY       joy_wolf
#
#                                                tweet  vader_score
# 0  upset cant update facebook texting might cry r...      -0.7269
# 1  dived many times ball managed save rest go bounds       0.4939
# 2                   whole body feels itchy like fire      -0.2500
# 3                           behaving im mad cant see      -0.4939
# 4                                         whole crew       0.0000

# %%
# Convert 'date' to datetime format if it's not already
df['date'] = pd.to_datetime(df['date'])

# Extract just the date part from the datetime
df['just_date'] = df['date'].dt.date

# Get distinct days
distinct_days = df['just_date'].unique()

# Display the distinct days
distinct_days
# Out:
# array([datetime.date(2009, 4, 6), datetime.date(2009, 4, 7),
#        datetime.date(2009, 4, 17), datetime.date(2009, 4, 18),
#        datetime.date(2009, 4, 19), datetime.date(2009, 4, 20),
#        datetime.date(2009, 4, 21), datetime.date(2009, 5, 1),
#        datetime.date(2009, 5, 2), datetime.date(2009, 5, 3),
#        datetime.date(2009, 5, 4), datetime.date(2009, 5, 9),
#        datetime.date(2009, 5, 10), datetime.date(2009, 5, 11),
#        datetime.date(2009, 5, 13), datetime.date(2009, 5, 14),
#        datetime.date(2009, 5, 16), datetime.date(2009, 5, 17),
#        datetime.date(2009, 5, 18), datetime.date(2009, 5, 21),
#        datetime.date(2009, 5, 22), datetime.date(2009, 5, 23),
#        datetime.date(2009, 5, 25), datetime.date(2009, 5, 26),
#        datetime.date(2009, 5, 27), datetime.date(2009, 5, 28),
#        datetime.date(2009, 5, 29), datetime.date(2009, 5, 30),
#        datetime.date(2009, 5, 31), datetime.date(2009, 6, 1),
#        datetime.date(2009, 6, 2), datetime.date(2009, 6, 3),
#        datetime.date(2009, 6, 4), datetime.date(2009, 6, 5),
#        datetime.date(2009, 6, 6), datetime.date(2009, 6, 7),
#        datetime.date(2009, 6, 14), datetime.date(2009, 6, 15),
#        datetime.date(2009, 6, 16), datetime.date(2009, 6, 17),
#        datetime.date(2009, 6, 18), datetime.date(2009, 6, 19),
#        datetime.date(2009, 6, 20), datetime.date(2009, 6, 21),
#        datetime.date(2009, 6, 22), datetime.date(2009, 6, 23),
#        datetime.date(2009, 6, 24), datetime.date(2009, 6, 25)],
#       dtype=object)

# %%
import pandas as pd

# Assuming df is your DataFrame
# Convert 'date' to datetime format if it's not already
df['date'] = pd.to_datetime(df['date'])

# Sort the DataFrame by the 'date' column
df = df.sort_values(by='date')

# Print the last few entries to verify the actual latest date
print(df.tail())

# Extract just the date part from the datetime
df['just_date'] = df['date'].dt.date

# Get distinct days
distinct_days = df['just_date'].unique()

# Display the distinct days and the actual latest date
print("Distinct Days:", distinct_days)
print("Actual Latest Date:", df['date'].iloc[-1])
# Out:
#            ids    tweet_id                date      flag          user  \
# 796328  796329  2329204987 2009-06-25 10:28:28  NO_QUERY     360cookie
# 796330  796331  2329205038 2009-06-25 10:28:28  NO_QUERY       bigenya
# 796332  796333  2329205574 2009-06-25 10:28:30  NO_QUERY  davidlmulder
# 796331  796332  2329205473 2009-06-25 10:28:30  NO_QUERY      LeeLHoke
# 796333  796334  2329205794 2009-06-25 10:28:31  NO_QUERY    tpchandler
#
#                                                     tweet  vader_score  \
# 796328  tried get mutant fawkes follow wouldnt lonely ...       0.2755
# 796330                                              gmail       0.0000
# 796332         sounds like rival flagging ads much though       0.3612
# 796331                              rest peace farrah sad       0.1027
# 796333  resit exams summer wishes worked harder first ...       0.1531
#
#          just_date
# 796328  2009-06-25
# 796330  2009-06-25
# 796332  2009-06-25
# 796331  2009-06-25
# 796333  2009-06-25
# Distinct Days: [datetime.date(2009, 4, 6) datetime.date(2009, 4, 7)
#  datetime.date(2009, 4, 17) datetime.date(2009, 4, 18)
#  datetime.date(2009, 4, 19) datetime.date(2009, 4, 20)
#  datetime.date(2009, 4, 21) datetime.date(2009, 5, 1)
#  datetime.date(2009, 5, 2) datetime.date(2009, 5, 3)
#  datetime.date(2009, 5, 4) datetime.date(2009, 5, 9)
#  datetime.date(2009, 5, 10) datetime.date(2009, 5, 11)
#  datetime.date(2009, 5, 13) datetime.date(2009, 5, 14)
#  datetime.date(2009, 5, 16) datetime.date(2009, 5, 17)
#  datetime.date(2009, 5, 18) datetime.date(2009, 5, 21)
#  datetime.date(2009, 5, 22) datetime.date(2009, 5, 23)
#  datetime.date(2009, 5, 25) datetime.date(2009, 5, 26)
#  datetime.date(2009, 5, 27) datetime.date(2009, 5, 28)
#  datetime.date(2009, 5, 29) datetime.date(2009, 5, 30)
#  datetime.date(2009, 5, 31) datetime.date(2009, 6, 1)
#  datetime.date(2009, 6, 2) datetime.date(2009, 6, 3)
#  datetime.date(2009, 6, 4) datetime.date(2009, 6, 5)
#  datetime.date(2009, 6, 6) datetime.date(2009, 6, 7)
#  datetime.date(2009, 6, 14) datetime.date(2009, 6, 15)
#  datetime.date(2009, 6, 16) datetime.date(2009, 6, 17)
#  datetime.date(2009, 6, 18) datetime.date(2009, 6, 19)
#  datetime.date(2009, 6, 20) datetime.date(2009, 6, 21)
#  datetime.date(2009, 6, 22) datetime.date(2009, 6, 23)
#  datetime.date(2009, 6, 24) datetime.date(2009, 6, 25)]
# Actual Latest Date: 2009-06-25 10:28:31

# %%
df1
# Out:
#            ids    tweet_id                date      flag           user  \
# 0            1  1467810672 2009-04-06 22:19:49  NO_QUERY  scotthamilton
# 1            2  1467810917 2009-04-06 22:19:53  NO_QUERY       mattycus
# 2            3  1467811184 2009-04-06 22:19:57  NO_QUERY        ElleCTF
# 3            4  1467811193 2009-04-06 22:19:57  NO_QUERY         Karoli
# 4            5  1467811372 2009-04-06 22:20:00  NO_QUERY       joy_wolf
# ...        ...         ...                 ...       ...            ...
# 796328  796329  2329204987 2009-06-25 10:28:28  NO_QUERY      360cookie
# 796330  796331  2329205038 2009-06-25 10:28:28  NO_QUERY        bigenya
# 796332  796333  2329205574 2009-06-25 10:28:30  NO_QUERY   davidlmulder
# 796331  796332  2329205473 2009-06-25 10:28:30  NO_QUERY       LeeLHoke
# 796333  796334  2329205794 2009-06-25 10:28:31  NO_QUERY     tpchandler
#
#                                                     tweet  vader_score  \
# 0       upset cant update facebook texting might cry r...      -0.7269
# 1       dived many times ball managed save rest go bounds       0.4939
# 2                        whole body feels itchy like fire      -0.2500
# 3                                behaving im mad cant see      -0.4939
# 4                                              whole crew       0.0000
# ...                                                   ...          ...
# 796328  tried get mutant fawkes follow wouldnt lonely ...       0.2755
# 796330                                              gmail       0.0000
# 796332         sounds like rival flagging ads much though       0.3612
# 796331                              rest peace farrah sad       0.1027
# 796333  resit exams summer wishes worked harder first ...       0.1531
#
#          just_date         day
# 0       2009-04-06  2009-04-06
# 1       2009-04-06  2009-04-06
# 2       2009-04-06  2009-04-06
# 3       2009-04-06  2009-04-06
# 4       2009-04-06  2009-04-06
# ...            ...         ...
# 796328  2009-06-25  2009-06-25
# 796330  2009-06-25  2009-06-25
# 796332  2009-06-25  2009-06-25
# 796331  2009-06-25  2009-06-25
# 796333  2009-06-25  2009-06-25
#
# [1590343 rows x 9 columns]

# %%
#df = df1.copy()

# %%
# backup
#df1= df.copy()

# %%
import pandas as pd

# Assuming 'df' is your DataFrame as shown in the screenshot
# Filter out rows where 'vader_score' is 0
df = df[df['vader_score'] != 0]

df
# Out:
#            ids    tweet_id                date      flag           user  \
# 0            1  1467810672 2009-04-06 22:19:49  NO_QUERY  scotthamilton
# 1            2  1467810917 2009-04-06 22:19:53  NO_QUERY       mattycus
# 2            3  1467811184 2009-04-06 22:19:57  NO_QUERY        ElleCTF
# 3            4  1467811193 2009-04-06 22:19:57  NO_QUERY         Karoli
# 5            6  1467811592 2009-04-06 22:20:03  NO_QUERY        mybirch
# ...        ...         ...                 ...       ...            ...
# 796329  796330  2329205009 2009-06-25 10:28:28  NO_QUERY       dandykim
# 796328  796329  2329204987 2009-06-25 10:28:28  NO_QUERY      360cookie
# 796332  796333  2329205574 2009-06-25 10:28:30  NO_QUERY   davidlmulder
# 796331  796332  2329205473 2009-06-25 10:28:30  NO_QUERY       LeeLHoke
# 796333  796334  2329205794 2009-06-25 10:28:31  NO_QUERY     tpchandler
#
#                                                     tweet  vader_score  \
# 0       upset cant update facebook texting might cry r...      -0.7269
# 1       dived many times ball managed save rest go bounds       0.4939
# 2                        whole body feels itchy like fire      -0.2500
# 3                                behaving im mad cant see      -0.4939
# 5                                                need hug       0.4767
# ...                                                   ...          ...
# 796329             sick spending day laying bed listening      -0.5106
# 796328  tried get mutant fawkes follow wouldnt lonely ...       0.2755
# 796332         sounds like rival flagging ads much though       0.3612
# 796331                              rest peace farrah sad       0.1027
# 796333  resit exams summer wishes worked harder first ...       0.1531
#
#          just_date         day
# 0       2009-04-06  2009-04-06
# 1       2009-04-06  2009-04-06
# 2       2009-04-06  2009-04-06
# 3       2009-04-06  2009-04-06
# 5       2009-04-06  2009-04-06
# ...            ...         ...
# 796329  2009-06-25  2009-06-25
# 796328  2009-06-25  2009-06-25
# 796332  2009-06-25  2009-06-25
# 796331  2009-06-25  2009-06-25
# 796333  2009-06-25  2009-06-25
#
# [1165663 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1590343 entries, 0 to 796333
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   ids          1590343 non-null  int64
#  1   tweet_id     1590343 non-null  int64
#  2   date         1590343 non-null  datetime64[ns]
#  3   flag         1590343 non-null  object
#  4   user         1590343 non-null  object
#  5   tweet        1590343 non-null  object
#  6   vader_score  1590343 non-null  float64
#  7   just_date    1590343 non-null  object
#  8   day          1590343 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 121.3+ MB

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
from collections import Counter

# Ensure that necessary nltk resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')


# Ensure 'date' is a datetime type
df['date'] = pd.to_datetime(df['date'])

# Filter DataFrame for the date range
mask = (df['date'] >= '2009-05-01') & (df['date'] <= '2009-05-10')
filtered_df = df.loc[mask]

# Concatenate all tweets into a single text
all_tweets = ' '.join(tweet for tweet in filtered_df['tweet'])

# Tokenize and filter stopwords
tokens = word_tokenize(all_tweets)
filtered_words = [word for word in tokens if word.isalnum()]  # Remove punctuation/numbers

# Removing stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in filtered_words if word.lower() not in stop_words]

# Count the frequency of each word
word_counts = Counter(filtered_words)

# Get the most common words
most_common_words = word_counts.most_common(10)  # You can adjust the number to get more or fewer common words

# Display the most common words and their counts
print(most_common_words)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jose\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jose\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [('im', 10510), ('good', 5992), ('day', 5627), ('like', 4732), ('get', 4609), ('go', 4307), ('love', 4215), ('got', 4070), ('going', 4039), ('today', 3885)]

# %%
from nltk import ngrams
from collections import Counter

# Generate bigrams
bigram_counts = Counter(ngrams(filtered_words, 2))

# Get the most common bigrams
most_common_bigrams = bigram_counts.most_common(10)
print("Most common bigrams:", most_common_bigrams)
# Out:
# Most common bigrams: [(('gon', 'na'), 1325), (('wan', 'na'), 868), (('last', 'night'), 790), (('cant', 'wait'), 789), (('mothers', 'day'), 715), (('good', 'morning'), 697), (('im', 'going'), 652), (('got', 'ta'), 541), (('dont', 'know'), 467), (('happy', 'mothers'), 398)]

# %%
from nltk import ngrams
from collections import Counter

# Assuming 'filtered_words' is a list of words from your dataset, already preprocessed

# Generate trigrams
trigram_counts = Counter(ngrams(filtered_words, 3))

# Get the most common trigrams
most_common_trigrams = trigram_counts.most_common(10)
print("Most common trigrams:", most_common_trigrams)
# Out:
# Most common trigrams: [(('happy', 'mothers', 'day'), 388), (('im', 'gon', 'na'), 337), (('wan', 'na', 'go'), 207), (('cant', 'wait', 'see'), 167), (('dont', 'wan', 'na'), 163), (('star', 'wars', 'day'), 110), (('gon', 'na', 'go'), 107), (('clean', 'clean', 'clean'), 95), (('happy', 'star', 'wars'), 85), (('got', 'ta', 'go'), 81)]

# %%
# Filter DataFrame for the date range
mask = (df['date'] >= '2009-05-22') & (df['date'] <= '2009-05-25')
filtered_df = df.loc[mask]

# Concatenate all tweets into a single text
all_tweets = ' '.join(tweet for tweet in filtered_df['tweet'])

# Tokenize and filter stopwords
tokens = word_tokenize(all_tweets)
filtered_words = [word for word in tokens if word.isalnum()]  # Remove punctuation/numbers

# Removing stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in filtered_words if word.lower() not in stop_words]

# Count the frequency of each word
word_counts = Counter(filtered_words)

# Get the most common words
most_common_words = word_counts.most_common(10)  # You can adjust the number to get more or fewer common words

# Display the most common words and their counts
print(most_common_words)
# Out:
# [('im', 3880), ('good', 2667), ('day', 2530), ('get', 1980), ('today', 1848), ('like', 1844), ('work', 1661), ('go', 1635), ('thanks', 1599), ('going', 1565)]

# %%
from nltk import ngrams
from collections import Counter

# Generate bigrams
bigram_counts = Counter(ngrams(filtered_words, 2))

# Get the most common bigrams
most_common_bigrams = bigram_counts.most_common(10)
print("Most common bigrams:", most_common_bigrams)
# Out:
# Most common bigrams: [(('gon', 'na'), 557), (('good', 'morning'), 460), (('cant', 'wait'), 373), (('last', 'night'), 329), (('wan', 'na'), 299), (('im', 'going'), 247), (('looking', 'forward'), 219), (('last', 'day'), 217), (('got', 'ta'), 208), (('dont', 'know'), 176)]

# %%
from nltk import ngrams
from collections import Counter

# Assuming 'filtered_words' is a list of words from your dataset, already preprocessed

# Generate trigrams
trigram_counts = Counter(ngrams(filtered_words, 3))

# Get the most common trigrams
most_common_trigrams = trigram_counts.most_common(10)
print("Most common trigrams:", most_common_trigrams)
# Out:
# Most common trigrams: [(('im', 'gon', 'na'), 141), (('wan', 'na', 'go'), 69), (('cant', 'wait', 'see'), 65), (('like', 'laughhave', 'good'), 51), (('laughhave', 'good', 'timefollow'), 51), (('good', 'timefollow', 'meits'), 51), (('timefollow', 'meits', 'simple'), 51), (('last', 'day', 'school'), 47), (('memorial', 'day', 'weekend'), 46), (('dont', 'wan', 'na'), 46)]

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
from collections import Counter

# Convert the 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'])

# Debug: Check the format of the first few dates
print("Dates after conversion:", df['date'].head())

# Filter DataFrame for the specific date
mask = (df['date'] == pd.Timestamp('2009-05-11'))
filtered_df = df.loc[mask]

# Debug: Check how many entries you have for May 11, 2009
print("Number of entries for 2009-05-11:", len(filtered_df))

# Ensure you have downloaded the necessary nltk resources
nltk.download('punkt')
nltk.download('stopwords')

# Concatenate all tweets into a single text
all_tweets = ' '.join(tweet for tweet in filtered_df['tweet'])

# Tokenize and filter stopwords
tokens = word_tokenize(all_tweets)
filtered_words = [word for word in tokens if word.isalnum()]  # Remove punctuation/numbers

# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in filtered_words if word.lower() not in stop_words]

# Count the frequency of each word
word_counts = Counter(filtered_words)

# Get the most common words
most_common_words = word_counts.most_common(10)  # You can adjust the number to get more or fewer common words

# Display the most common words and their counts
print("Most common words:", most_common_words)
# Out:
# Dates after conversion: 0   2009-04-06 22:19:49
# 1   2009-04-06 22:19:53
# 2   2009-04-06 22:19:57
# 3   2009-04-06 22:19:57
# 4   2009-04-06 22:20:00
# Name: date, dtype: datetime64[ns]
# Number of entries for 2009-05-11: 0
# Most common words: []
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jose\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jose\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 796328    False
# 796330    False
# 796332    False
# 796331    False
# 796333    False
# Name: date, Length: 1590343, dtype: bool

# %%
from nltk import ngrams
from collections import Counter

# Generate bigrams
bigram_counts = Counter(ngrams(filtered_words, 2))

# Get the most common bigrams
most_common_bigrams = bigram_counts.most_common(10)
print("Most common bigrams:", most_common_bigrams)
# Out:
# Most common bigrams: []

# %%
from nltk import ngrams
from collections import Counter

# Assuming 'filtered_words' is a list of words from your dataset, already preprocessed

# Generate trigrams
trigram_counts = Counter(ngrams(filtered_words, 3))

# Get the most common trigrams
most_common_trigrams = trigram_counts.most_common(10)
print("Most common trigrams:", most_common_trigrams)
# Out:
# Most common trigrams: []

# %%
# Filter DataFrame for the date range
mask = (df['date'] >= '2009-05-29') & (df['date'] <= '2009-06-14')
filtered_df = df.loc[mask]

# Concatenate all tweets into a single text
all_tweets = ' '.join(tweet for tweet in filtered_df['tweet'])

# Tokenize and filter stopwords
tokens = word_tokenize(all_tweets)
filtered_words = [word for word in tokens if word.isalnum()]  # Remove punctuation/numbers

# Removing stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in filtered_words if word.lower() not in stop_words]

# Count the frequency of each word
word_counts = Counter(filtered_words)

# Get the most common words
most_common_words = word_counts.most_common(20)  # You can adjust the number to get more or fewer common words

# Display the most common words and their counts
print(most_common_words)
# Out:
# [('im', 82707), ('good', 44864), ('get', 37226), ('day', 36984), ('like', 36468), ('love', 34126), ('go', 33220), ('got', 32840), ('going', 30248), ('dont', 29507), ('today', 29105), ('lol', 28435), ('cant', 27624), ('time', 26872), ('u', 26657), ('back', 25748), ('work', 25689), ('one', 24551), ('know', 24360), ('see', 22907)]

# %%
from nltk import ngrams
from collections import Counter

# Generate bigrams
bigram_counts = Counter(ngrams(filtered_words, 2))

# Get the most common bigrams
most_common_bigrams = bigram_counts.most_common(20)
print("Most common bigrams:", most_common_bigrams)
# Out:
# Most common bigrams: [(('gon', 'na'), 11204), (('cant', 'wait'), 7330), (('wan', 'na'), 7255), (('last', 'night'), 5458), (('im', 'going'), 4945), (('good', 'morning'), 4657), (('got', 'ta'), 4125), (('dont', 'know'), 3625), (('im', 'gon'), 2957), (('wish', 'could'), 2656), (('feel', 'like'), 2647), (('looking', 'forward'), 2624), (('im', 'sorry'), 2588), (('good', 'luck'), 2557), (('na', 'go'), 2530), (('dont', 'want'), 2400), (('getting', 'ready'), 2368), (('looks', 'like'), 2279), (('good', 'night'), 2268), (('im', 'sure'), 2000)]

# %%
from nltk import ngrams
from collections import Counter

# Assuming 'filtered_words' is a list of words from your dataset, already preprocessed

# Generate trigrams
trigram_counts = Counter(ngrams(filtered_words, 3))

# Get the most common trigrams
most_common_trigrams = trigram_counts.most_common(20)
print("Most common trigrams:", most_common_trigrams)
# Out:
# Most common trigrams: [(('im', 'gon', 'na'), 2941), (('wan', 'na', 'go'), 1617), (('mtv', 'movie', 'awards'), 1333), (('cant', 'wait', 'see'), 1260), (('dont', 'wan', 'na'), 1154), (('gon', 'na', 'go'), 912), (('get', 'followers', 'day'), 831), (('followers', 'day', 'using'), 830), (('day', 'using', 'wwwtweeteraddercom'), 830), (('using', 'wwwtweeteraddercom', 'add'), 830), (('wwwtweeteraddercom', 'add', 'everyone'), 830), (('add', 'everyone', 'train'), 830), (('everyone', 'train', 'pay'), 830), (('train', 'pay', 'vip'), 830), (('gon', 'na', 'miss'), 796), (('wan', 'na', 'see'), 679), (('new', 'moon', 'trailer'), 611), (('gon', 'na', 'get'), 545), (('got', 'ta', 'go'), 504), (('cant', 'wait', 'till'), 466)]

# %%
# Filter DataFrame for the date range
mask = (df['date'] >= '2009-06-15') & (df['date'] <= '2009-06-20')
filtered_df = df.loc[mask]

# Concatenate all tweets into a single text
all_tweets = ' '.join(tweet for tweet in filtered_df['tweet'])

# Tokenize and filter stopwords
tokens = word_tokenize(all_tweets)
filtered_words = [word for word in tokens if word.isalnum()]  # Remove punctuation/numbers

# Removing stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in filtered_words if word.lower() not in stop_words]

# Count the frequency of each word
word_counts = Counter(filtered_words)

# Get the most common words
most_common_words = word_counts.most_common(100)  # You can adjust the number to get more or fewer common words

# Display the most common words and their counts
print(most_common_words)
# Out:
# [('im', 37304), ('get', 17816), ('day', 16115), ('like', 15559), ('go', 15280), ('dont', 15139), ('work', 14666), ('good', 14470), ('got', 14295), ('cant', 14041), ('today', 13234), ('going', 12444), ('back', 11122), ('really', 10560), ('time', 10447), ('one', 10426), ('know', 9959), ('still', 9727), ('u', 9714), ('want', 9634), ('love', 9590), ('lol', 9441), ('miss', 9092), ('na', 8887), ('think', 8287), ('home', 8274), ('well', 8173), ('see', 8034), ('new', 7962), ('need', 7880), ('oh', 7702), ('amp', 7446), ('sad', 7141), ('feel', 7112), ('much', 7019), ('last', 6934), ('tomorrow', 6792), ('bad', 6671), ('night', 6625), ('wish', 6528), ('didnt', 6169), ('sorry', 6033), ('morning', 6022), ('hope', 5998), ('ill', 5845), ('sleep', 5679), ('right', 5583), ('thats', 5490), ('twitter', 5476), ('would', 5476), ('thanks', 5124), ('hate', 5090), ('getting', 5076), ('haha', 5057), ('though', 4906), ('gon', 4820), ('ive', 4797), ('make', 4753), ('come', 4739), ('tonight', 4553), ('great', 4519), ('way', 4516), ('could', 4516), ('school', 4401), ('better', 4345), ('week', 4242), ('bed', 4224), ('even', 4152), ('sick', 4144), ('fun', 4138), ('wait', 4091), ('days', 4012), ('wont', 3865), ('people', 3855), ('yeah', 3854), ('wan', 3844), ('never', 3842), ('working', 3710), ('tired', 3684), ('happy', 3586), ('feeling', 3491), ('next', 3477), ('iphone', 3370), ('take', 3356), ('nice', 3324), ('watching', 3321), ('long', 3312), ('phone', 3301), ('little', 3255), ('soon', 3252), ('youre', 3252), ('doesnt', 3239), ('already', 3165), ('first', 3154), ('find', 3094), ('yet', 3046), ('everyone', 3040), ('another', 3000), ('please', 2995), ('rain', 2966)]

# %%
from nltk import ngrams
from collections import Counter

# Generate bigrams
bigram_counts = Counter(ngrams(filtered_words, 2))

# Get the most common bigrams
most_common_bigrams = bigram_counts.most_common(100)
print("Most common bigrams:", most_common_bigrams)
# Out:
# Most common bigrams: [(('gon', 'na'), 4769), (('wan', 'na'), 3815), (('im', 'going'), 2172), (('cant', 'wait'), 2029), (('last', 'night'), 1998), (('dont', 'know'), 1890), (('got', 'ta'), 1838), (('feel', 'like'), 1705), (('wish', 'could'), 1614), (('im', 'sorry'), 1553), (('good', 'morning'), 1516), (('dont', 'want'), 1432), (('im', 'gon'), 1379), (('na', 'go'), 1333), (('looks', 'like'), 1146), (('dont', 'think'), 1138), (('want', 'go'), 1110), (('cant', 'sleep'), 960), (('looking', 'forward'), 910), (('last', 'day'), 901), (('cant', 'believe'), 893), (('im', 'still'), 859), (('didnt', 'get'), 855), (('oh', 'well'), 845), (('think', 'im'), 825), (('dont', 'like'), 820), (('cant', 'get'), 819), (('go', 'back'), 817), (('getting', 'ready'), 781), (('good', 'luck'), 780), (('back', 'work'), 772), (('dont', 'wan'), 766), (('go', 'home'), 764), (('im', 'sad'), 763), (('im', 'tired'), 733), (('sorry', 'hear'), 716), (('cant', 'find'), 703), (('ive', 'got'), 688), (('next', 'week'), 684), (('im', 'sure'), 680), (('get', 'followers'), 678), (('im', 'getting'), 676), (('dont', 'get'), 658), (('going', 'bed'), 658), (('feel', 'better'), 657), (('followers', 'day'), 635), (('day', 'using'), 630), (('add', 'everyone'), 629), (('using', 'wwwtweeterfollowcom'), 628), (('wwwtweeterfollowcom', 'add'), 628), (('everyone', 'train'), 628), (('train', 'pay'), 628), (('pay', 'vip'), 628), (('cant', 'go'), 607), (('go', 'work'), 604), (('im', 'really'), 598), (('good', 'day'), 584), (('dont', 'feel'), 578), (('got', 'home'), 558), (('good', 'night'), 547), (('come', 'back'), 539), (('im', 'bored'), 534), (('sounds', 'like'), 521), (('really', 'want'), 519), (('work', 'today'), 515), (('know', 'im'), 507), (('go', 'bed'), 501), (('get', 'back'), 498), (('like', 'im'), 491), (('na', 'miss'), 485), (('happy', 'birthday'), 484), (('got', 'back'), 469), (('work', 'tomorrow'), 466), (('feel', 'bad'), 463), (('first', 'day'), 456), (('today', 'im'), 453), (('im', 'sick'), 448), (('feels', 'like'), 447), (('long', 'day'), 445), (('great', 'day'), 442), (('ice', 'cream'), 441), (('let', 'know'), 432), (('back', 'home'), 432), (('wont', 'let'), 425), (('really', 'really'), 425), (('need', 'get'), 419), (('day', 'today'), 413), (('next', 'time'), 409), (('one', 'day'), 408), (('jonas', 'brothers'), 405), (('lol', 'im'), 395), (('first', 'time'), 393), (('go', 'away'), 387), (('dont', 'even'), 386), (('day', 'work'), 382), (('day', 'im'), 380), (('makes', 'sad'), 378), (('really', 'bad'), 374), (('could', 'go'), 374), (('going', 'miss'), 374)]

# %%
from nltk import ngrams
from collections import Counter

# Assuming 'filtered_words' is a list of words from your dataset, already preprocessed

# Generate trigrams
trigram_counts = Counter(ngrams(filtered_words, 3))

# Get the most common trigrams
most_common_trigrams = trigram_counts.most_common(200)
print("Most common trigrams:", most_common_trigrams)
# Out:
# Most common trigrams: [(('im', 'gon', 'na'), 1374), (('wan', 'na', 'go'), 1020), (('dont', 'wan', 'na'), 764), (('get', 'followers', 'day'), 628), (('followers', 'day', 'using'), 628), (('day', 'using', 'wwwtweeterfollowcom'), 628), (('using', 'wwwtweeterfollowcom', 'add'), 628), (('wwwtweeterfollowcom', 'add', 'everyone'), 628), (('add', 'everyone', 'train'), 628), (('everyone', 'train', 'pay'), 628), (('train', 'pay', 'vip'), 628), (('gon', 'na', 'miss'), 474), (('gon', 'na', 'go'), 313), (('cant', 'wait', 'see'), 288), (('dont', 'want', 'go'), 264), (('got', 'ta', 'go'), 256), (('wish', 'could', 'go'), 241), (('wan', 'na', 'see'), 230), (('gon', 'na', 'get'), 223), (('got', 'ta', 'get'), 214), (('dont', 'feel', 'good'), 209), (('im', 'going', 'miss'), 206), (('hope', 'feel', 'better'), 202), (('feel', 'like', 'im'), 191), (('lines', 'vines', 'trying'), 174), (('last', 'day', 'school'), 172), (('vines', 'trying', 'times'), 170), (('cant', 'wait', 'till'), 165), (('im', 'sorry', 'hear'), 159), (('really', 'wan', 'na'), 156), (('na', 'go', 'home'), 155), (('want', 'go', 'home'), 154), (('think', 'im', 'going'), 152), (('dont', 'feel', 'like'), 147), (('please', 'help', 'find'), 147), (('getting', 'ready', 'go'), 147), (('help', 'find', 'good'), 145), (('find', 'good', 'home'), 145), (('lost', 'please', 'help'), 144), (('cant', 'wait', 'get'), 138), (('dont', 'even', 'know'), 137), (('wan', 'na', 'get'), 134), (('feel', 'better', 'soon'), 130), (('go', 'back', 'sleep'), 126), (('getting', 'ready', 'work'), 123), (('think', 'im', 'gon'), 121), (('im', 'going', 'bed'), 117), (('teen', 'choice', 'awards'), 117), (('dont', 'know', 'im'), 110), (('sleep', 'last', 'night'), 109), (('want', 'go', 'back'), 109), (('na', 'go', 'back'), 109), (('get', 'well', 'soon'), 108), (('really', 'dont', 'want'), 107), (('good', 'morning', 'everyone'), 106), (('feel', 'like', 'crap'), 106), (('im', 'getting', 'sick'), 106), (('gon', 'na', 'make'), 104), (('think', 'im', 'getting'), 102), (('im', 'pretty', 'sure'), 100), (('got', 'ta', 'love'), 98), (('got', 'ta', 'work'), 98), (('gon', 'na', 'take'), 97), (('rain', 'rain', 'go'), 95), (('wan', 'na', 'come'), 93), (('rain', 'go', 'away'), 93), (('go', 'back', 'work'), 92), (('wan', 'na', 'watch'), 90), (('especially', 'youve', 'got'), 89), (('jogging', 'isnt', 'really'), 88), (('isnt', 'really', 'cool'), 88), (('really', 'cool', 'especially'), 88), (('cool', 'especially', 'youve'), 88), (('want', 'go', 'work'), 85), (('gon', 'na', 'try'), 85), (('dont', 'feel', 'well'), 84), (('really', 'really', 'really'), 83), (('get', 'ready', 'work'), 81), (('back', 'work', 'tomorrow'), 81), (('dont', 'think', 'im'), 80), (('feel', 'like', 'shit'), 80), (('make', 'feel', 'better'), 79), (('cant', 'fall', 'asleep'), 76), (('really', 'want', 'go'), 76), (('gon', 'na', 'long'), 76), (('cant', 'believe', 'im'), 76), (('cant', 'wait', 'go'), 75), (('anyone', 'wan', 'na'), 73), (('dont', 'think', 'ill'), 73), (('youve', 'got', 'fever'), 72), (('go', 'back', 'bed'), 71), (('wan', 'na', 'sleep'), 71), (('wan', 'na', 'cry'), 71), (('looks', 'like', 'im'), 70), (('wish', 'could', 'come'), 68), (('cant', 'wait', 'til'), 68), (('im', 'going', 'go'), 68), (('gon', 'na', 'cry'), 68), (('wan', 'na', 'play'), 68), (('gon', 'na', 'see'), 68), (('youre', 'gon', 'na'), 68), (('today', 'gon', 'na'), 67), (('really', 'looking', 'forward'), 65), (('wish', 'could', 'see'), 65), (('im', 'going', 'sleep'), 65), (('dont', 'want', 'work'), 65), (('im', 'looking', 'forward'), 65), (('wan', 'na', 'work'), 65), (('status', 'update', 'twitter'), 65), (('update', 'twitter', 'ice'), 65), (('twitter', 'ice', 'timestamp'), 65), (('ice', 'timestamp', 'mon'), 65), (('timestamp', 'mon', 'jun'), 65), (('mon', 'jun', 'cest'), 65), (('im', 'going', 'get'), 64), (('got', 'ta', 'wait'), 64), (('wan', 'na', 'know'), 63), (('cant', 'wait', 'hear'), 63), (('gon', 'na', 'watch'), 63), (('x', 'x', 'x'), 61), (('cant', 'go', 'back'), 61), (('doesnt', 'look', ' ...

# %%
from nltk import ngrams
from collections import Counter

# Assuming 'filtered_words' is a list of words from your dataset, already preprocessed

# Generate trigrams
trigram_counts = Counter(ngrams(filtered_words, 4))

# Get the most common trigrams
most_common_trigrams = trigram_counts.most_common(200)
print("Most common trigrams:", most_common_trigrams)
# Out:
# Most common trigrams: [(('get', 'followers', 'day', 'using'), 628), (('followers', 'day', 'using', 'wwwtweeterfollowcom'), 628), (('day', 'using', 'wwwtweeterfollowcom', 'add'), 628), (('using', 'wwwtweeterfollowcom', 'add', 'everyone'), 628), (('wwwtweeterfollowcom', 'add', 'everyone', 'train'), 628), (('add', 'everyone', 'train', 'pay'), 628), (('everyone', 'train', 'pay', 'vip'), 628), (('im', 'gon', 'na', 'miss'), 254), (('dont', 'wan', 'na', 'go'), 221), (('lines', 'vines', 'trying', 'times'), 163), (('wan', 'na', 'go', 'home'), 151), (('lost', 'please', 'help', 'find'), 144), (('please', 'help', 'find', 'good'), 144), (('help', 'find', 'good', 'home'), 144), (('think', 'im', 'gon', 'na'), 121), (('wan', 'na', 'go', 'back'), 100), (('im', 'gon', 'na', 'go'), 89), (('jogging', 'isnt', 'really', 'cool'), 88), (('isnt', 'really', 'cool', 'especially'), 88), (('really', 'cool', 'especially', 'youve'), 88), (('cool', 'especially', 'youve', 'got'), 88), (('rain', 'rain', 'go', 'away'), 84), (('hope', 'feel', 'better', 'soon'), 80), (('especially', 'youve', 'got', 'fever'), 72), (('status', 'update', 'twitter', 'ice'), 65), (('update', 'twitter', 'ice', 'timestamp'), 65), (('twitter', 'ice', 'timestamp', 'mon'), 65), (('ice', 'timestamp', 'mon', 'jun'), 65), (('timestamp', 'mon', 'jun', 'cest'), 65), (('im', 'gon', 'na', 'get'), 64), (('really', 'wan', 'na', 'go'), 60), (('dont', 'want', 'go', 'work'), 58), (('wan', 'na', 'go', 'work'), 54), (('think', 'im', 'getting', 'sick'), 51), (('im', 'gon', 'na', 'cry'), 45), (('cant', 'go', 'back', 'sleep'), 45), (('dont', 'wan', 'na', 'work'), 44), (('dont', 'wan', 'na', 'get'), 41), (('dont', 'wan', 'na', 'leave'), 41), (('fever', 'jogging', 'isnt', 'really'), 41), (('got', 'ta', 'go', 'work'), 39), (('know', 'im', 'gon', 'na'), 36), (('youve', 'got', 'fever', 'jogging'), 35), (('got', 'fever', 'jogging', 'isnt'), 35), (('like', 'im', 'gon', 'na'), 34), (('im', 'gon', 'na', 'try'), 34), (('didnt', 'understand', 'try', 'commands'), 34), (('understand', 'try', 'commands', 'like'), 34), (('try', 'commands', 'like', 'buy'), 34), (('commands', 'like', 'buy', 'sell'), 34), (('im', 'gon', 'na', 'make'), 31), (('gon', 'na', 'long', 'day'), 31), (('looks', 'like', 'gon', 'na'), 30), (('really', 'dont', 'wan', 'na'), 30), (('really', 'really', 'really', 'really'), 29), (('bored', 'studying', 'bored', 'studying'), 29), (('gon', 'na', 'miss', 'everyone'), 27), (('x', 'x', 'x', 'x'), 26), (('wan', 'na', 'go', 'sleep'), 26), (('dont', 'want', 'go', 'school'), 26), (('dont', 'feel', 'like', 'going'), 26), (('lines', 'vines', 'amp', 'trying'), 26), (('vines', 'amp', 'trying', 'times'), 26), (('really', 'dont', 'want', 'go'), 26), (('dont', 'want', 'go', 'back'), 25), (('wan', 'na', 'go', 'see'), 25), (('wan', 'na', 'go', 'school'), 25), (('hope', 'get', 'better', 'soon'), 24), (('watching', 'angels', 'demons', 'lt'), 24), (('angels', 'demons', 'lt', 'free'), 24), (('im', 'gon', 'na', 'see'), 23), (('getting', 'ready', 'go', 'work'), 22), (('hope', 'things', 'get', 'better'), 22), (('hope', 'u', 'feel', 'better'), 22), (('cant', 'wait', 'get', 'home'), 22), (('vote', 'teen', 'choice', 'awards'), 22), (('dont', 'think', 'im', 'going'), 21), (('want', 'go', 'back', 'work'), 21), (('hope', 'youre', 'feeling', 'better'), 21), (('bad', 'bad', 'bad', 'bad'), 21), (('gon', 'na', 'go', 'bed'), 20), (('got', 'ta', 'get', 'early'), 20), (('got', 'ta', 'go', 'back'), 20), (('today', 'im', 'gon', 'na'), 20), (('im', 'gon', 'na', 'need'), 20), (('dont', 'know', 'im', 'going'), 20), (('hours', 'sleep', 'last', 'night'), 19), (('dont', 'think', 'ive', 'ever'), 19), (('got', 'ta', 'get', 'ready'), 19), (('im', 'gon', 'na', 'die'), 19), (('feel', 'like', 'im', 'going'), 19), (('tomorrow', 'im', 'gon', 'na'), 18), (('guess', 'im', 'gon', 'na'), 18), (('gon', 'na', 'good', 'day'), 18), (('im', 'ready', 'go', 'home'), 18), (('na', 'go', 'back', 'bed'), 18), (('wan', 'na', 'go', 'beach'), 18), (('gon', 'na', 'miss', 'u'),  ...

# %%
# Convert 'date' to datetime format
df['date'] = pd.to_datetime(df['date'])
# Calculatint the time difference
time_difference = df['date'].iloc[-1] - df['date'].iloc[0]

# Print the result
print('First tweet send out the 2009-04-06 22:19:49 and last one  2009-06-16 08:40:50')

# Print the result
print('Total time difference:',time_difference)
# Out:
# First tweet send out the 2009-04-06 22:19:49 and last one  2009-06-16 08:40:50
# Total time difference: 79 days 12:08:42

# %%
df['date'] = pd.to_datetime(df['date'])
# Strip time part to just keep the date
df['day'] = df['date'].dt.date

# %%
# Group by the date and count tweets
sentiment_average = df.groupby('day')['vader_score'].mean()

# %%
sentiment_average
# Out:
# day
# 2009-04-06    0.149710
# 2009-04-07    0.168952
# 2009-04-17    0.204442
# 2009-04-18    0.183523
# 2009-04-19    0.189118
# 2009-04-20    0.181151
# 2009-04-21    0.181557
# 2009-05-01    0.180541
# 2009-05-02    0.183295
# 2009-05-03    0.175477
# 2009-05-04    0.170850
# 2009-05-09    0.185756
# 2009-05-10    0.214157
# 2009-05-11    0.166859
# 2009-05-13    0.147983
# 2009-05-14    0.174673
# 2009-05-16    0.174701
# 2009-05-17    0.202786
# 2009-05-18    0.190769
# 2009-05-21    0.177463
# 2009-05-22    0.200422
# 2009-05-23    0.206487
# 2009-05-25    0.190222
# 2009-05-26    0.175078
# 2009-05-27    0.136196
# 2009-05-28    0.187763
# 2009-05-29    0.186463
# 2009-05-30    0.193465
# 2009-05-31    0.194989
# 2009-06-01    0.176648
# 2009-06-02    0.178337
# 2009-06-03    0.175142
# 2009-06-04    0.161818
# 2009-06-05    0.186798
# 2009-06-06    0.184296
# 2009-06-07    0.184579
# 2009-06-14    0.174186
# 2009-06-15    0.170982
# 2009-06-16    0.095041
# 2009-06-17   -0.014981
# 2009-06-18   -0.018223
# 2009-06-19   -0.013317
# 2009-06-20   -0.007726
# 2009-06-21    0.003513
# 2009-06-22   -0.033130
# 2009-06-23   -0.020902
# 2009-06-24   -0.017719
# 2009-06-25   -0.021246
# Name: vader_score, dtype: float64

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(sentiment_average.index, sentiment_average.values)
plt.title('Sentiment analysis overtime')
plt.xlabel('Date')
plt.ylabel('Vader Score')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Assuming 'sentiment_average' is a DataFrame with a datetime index
plt.figure(figsize=(12, 6))  # You can adjust the size as needed

# Set the locator for major and minor axis ticks to display more date ticks
locator = mdates.AutoDateLocator(minticks=3, maxticks=7)
formatter = mdates.ConciseDateFormatter(locator)
plt.gca().xaxis.set_major_locator(locator)
plt.gca().xaxis.set_major_formatter(formatter)

plt.plot(sentiment_average.index, sentiment_average.values)
plt.title('Sentiment Analysis Overtime')
plt.xlabel('Date')
plt.ylabel('Vader Score')
plt.grid(True)

plt.show()

# %%
# Saving df
df.to_csv('C:/Users/jose/Downloads/ProjectTweetsVAder.csv', index=False, header=True, encoding='utf-8', sep=',')
